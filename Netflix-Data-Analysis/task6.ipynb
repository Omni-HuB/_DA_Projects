# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df = pd.read_csv('Python Dataset/netflix.csv')
df
# Out:
#                                                  title               genre  \
# 0                                     Notes for My Son               Drama
# 1                                     To Each, Her Own     Romantic comedy
# 2                                        The Lovebirds     Romantic comedy
# 3                                       The Perfection     Horror-thriller
# 4                                    Happy Anniversary     Romantic comedy
# ..                                                 ...                 ...
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...         Documentary
# 579                           Freaks: You're One of Us  Supernatural drama
# 580                                       Squared Love     Romantic comedy
# 581                                         My Own Man         Documentary
# 582                      Biggie: I Got a Story to Tell         Documentary
#
#     language  imdb_score    premiere  runtime  year
# ...

# %%
df.shape
# Out:
# (583, 7)

# %%
df.columns.values
# Out:
# array(['title', 'genre', 'language', 'imdb_score', 'premiere', 'runtime',
#        'year'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       583 non-null    object
#  1   genre       583 non-null    object
#  2   language    583 non-null    object
#  3   imdb_score  583 non-null    float64
#  4   premiere    583 non-null    object
#  5   runtime     583 non-null    int64
#  6   year        583 non-null    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 32.0+ KB

# %%
df.isnull().sum()
# Out:
# title         0
# genre         0
# language      0
# imdb_score    0
# premiere      0
# runtime       0
# year          0
# dtype: int64

# %%
df.hist( bins = 50, grid = False, figsize=(12,10))
# Out:
# array([[<Axes: title={'center': 'imdb_score'}>,
#         <Axes: title={'center': 'runtime'}>],
#        [<Axes: title={'center': 'year'}>, <Axes: >]], dtype=object)

# %%
sns.boxplot( data = df)
# Out:
# <Axes: >

# %%
questions = [
    
    '1. what is the distribution of movies on netflix based on genre?',
    
    '2. What are movies on Netflix having imdb_score>=8?',
    
    '3. List 10 drama movies released on Netflix after year 2018 having imdb_score>=7?',
    
    '4. In which year maximum number of videos released on netflix?',
    
    '5. In which genre most of the videos released on netflix after year 2016?'
    
]
questions
# Out:
# ['1. what is the distribution of movies on netflix based on genre?',
#  '2. What are movies on Netflix having imdb_score>=8?',
#  '3. List 10 drama movies released on Netflix after year 2018 having imdb_score>=7?',
#  '4. In which year maximum number of videos released on netflix?',
#  '5. In which genre most of the videos released on netflix after year 2016?']

# %% [markdown]
# <h1> 1. What is the distribution of movies on netflix based on genre?

# %%
df.genre.value_counts()
# Out:
# genre
# Documentary                    159
# Drama                           77
# Comedy                          49
# Romantic comedy                 39
# Thriller                        33
#                               ...
# Political thriller               1
# Fantasy                          1
# Romantic comedy-drama            1
# Animation/Musical/Adventure      1
# Supernatural drama               1
# Name: count, Length: 114, dtype: int64

# %%
df.genre.value_counts().plot(kind='bar',figsize=(60,30))
# Out:
# <Axes: xlabel='genre'>

# %% [markdown]
# <h1>2. What are movies on Netflix having imdb_score>=8?

# %%
top10moviesi9 = df[df['imdb_score']>=8].sort_values(by='imdb_score', ascending=False)
top10moviesi9
# Out:
#                                             title  \
# 285      David Attenborough: A Life on Our Planet
# 268     Emicida: AmarElo - It's All For Yesterday
# 72                        Springsteen on Broadway
# 515         Taylor Swift: Reputation Stadium Tour
# 214   Winter on Fire: Ukraine's Fight for Freedom
# 410    Ben Platt: Live from Radio City Music Hall
# 331                        Dancing with the Birds
# 101                       Cuba and the Cameraman
# 396                                         Klaus
# 369                                    Seaspiracy
# 390             Disclosure: Trans Lives on Screen
# 179                                          13th
# 519         The Three Deaths of Marisela Escobedo
# 363                            My Octopus Teacher
# 457                                Chasing Coral
# 462                                Rising Phoenix
# 392  Struggle: The Life and Lost Art of Szukaiski
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'imdb_score', y = 'title', data = top10moviesi9, palette='viridis')
plt.title('Top movies on Netflix having imdb_score>=8')
plt.xlabel('IMDB Score')
plt.ylabel('Movies Names')
# plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>3. List 10 Drama movies released on Netflix after year 2018 having imdb_score>=7?

# %%
top10dramai8 = df[(df['imdb_score']>=7) & (df['genre']=='Drama') & (df['year']>=2018)].sort_values(by='imdb_score', ascending=False).head(10)
top10dramai8
# Out:
#                           title  genre language  imdb_score    premiere  \
# 270              Marriage Story  Drama  English         7.9   12/6/2019
# 52   The Trial of the Chicago 7  Drama  English         7.8  10/16/2020
# 274                        Roma  Drama  Spanish         7.7  12/14/2018
# 61                   Yeh Ballet  Drama    Hindi         7.6   2/21/2020
# 355               The Two Popes  Drama  English         7.6  12/20/2019
# 74           I'm No Longer Here  Drama  Spanish         7.3   5/27/2020
# 220                   Sometimes  Drama    Tamil         7.2    5/1/2018
# 278                Private Life  Drama  English         7.2   10/5/2018
# 534                The Disciple  Drama  Marathi         7.2   4/30/2021
# 18            Pieces of a Woman  Drama  English         7.1    1/7/2021
#
#      runtime  year
# 270      136  2019
# 52       130  2020
# 274      135  2018
# 61       117  2020
# 355      125  2019
# 74       105  2020
# 220      101  2018
# ...

# %%
top10dramai8.plot(kind='bar', x='title', y='imdb_score', figsize=(10,6))
# Out:
# <Axes: xlabel='title'>

# %%
sns.barplot(x = 'imdb_score', y = 'title', data = top10dramai8, palette='viridis')
plt.title('Top 10 Drama TV shows on Netflix having imdb_score>=8 after year 2018')
plt.xlabel('IMDB Score')
plt.ylabel('TV Shows Names')
plt.show()

# %% [markdown]
# <h1> 4. In which year maximum number of videos released on netflix?

# %%
df['year'].value_counts().idxmax()
# Out:
# 2020

# %%
maxNoOfVideos = df['year'].value_counts()
maxNoOfVideos
# Out:
# year
# 2020    182
# 2019    125
# 2018     99
# 2021     71
# 2017     66
# 2016     30
# 2015      9
# 2014      1
# Name: count, dtype: int64

# %%
sns.barplot(x = maxNoOfVideos.index, y = maxNoOfVideos.values, palette='viridis')
plt.title('Maximum number of videos released on Netflix in which year?')
plt.xlabel('Year')
plt.ylabel('Number of Videos')
plt.show()

# %%
plt.figure(figsize=(20, 8))
clr = sns.color_palette('rainbow')

# Format to display count and percentage
autopct = lambda pct: f'{pct:.1f}%\n({round(pct/100.*sum(maxNoOfVideos))})'

plt.pie(maxNoOfVideos, labels=maxNoOfVideos.index, colors=clr, autopct=autopct, startangle=70)
plt.title('Maximum number of videos released on Netflix in which year?')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <h1> 5. In which genre most of the videos released on netflix after year 2016?

# %%
df.groupby('genre')['year'].value_counts()
# Out:
# genre          year
# Action         2019    4
#                2020    2
#                2021    1
# Action comedy  2020    3
#                2016    2
#                       ..
# War-Comedy     2017    1
# Western        2017    1
#                2015    1
#                2018    1
# Zombie/Heist   2021    1
# Name: count, Length: 199, dtype: int64

# %%
# Filter the DataFrame to include only rows where the year is greater than 2016
filtered_df = df[df['year'] > 2016]

# Group by genre and count the number of occurrences
result = filtered_df.groupby('genre')['year'].count()
result
# Out:
# genre
# Action              7
# Action comedy       3
# Action thriller     1
# Action-adventure    1
# Action-thriller     3
#                    ..
# War                 1
# War drama           1
# War-Comedy          1
# Western             2
# Zombie/Heist        1
# Name: year, Length: 113, dtype: int64

# %%
result.idxmax()
# Out:
# 'Documentary'

# %%
# Filter the DataFrame to include only rows where the year is greater than 2016
filtered_df = df[df['year'] > 2016]

# Group by genre and count the number of occurrences
result = filtered_df.groupby('genre')['year'].value_counts()
result
# Out:
# genre            year
# Action           2019    4
#                  2020    2
#                  2021    1
# Action comedy    2020    3
# Action thriller  2017    1
#                         ..
# War drama        2020    1
# War-Comedy       2017    1
# Western          2017    1
#                  2018    1
# Zombie/Heist     2021    1
# Name: count, Length: 179, dtype: int64

# %%
result.unstack().plot(kind='bar', stacked=True, figsize=(20, 10))

plt.title('In which genre most of the videos released on netflix after year 2016?')
plt.xlabel('Genre')
plt.ylabel('Number of Videos')
plt.show()

# %% [markdown]
# #### Documentary in the genre in which around 140 movies were released after year 2016 followed by Drama = 75
